# %% [markdown]
# <font size=6><b>Lec03.딥러닝 모델 - 회귀

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#----------------------------------------------------------------------------------- ML 모델
from xgboost import XGBRegressor 
#----------------------------------------------------------------------------------  DL모델 
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
#-----------------------------------------------------------------------------------  평가
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

sns.set()

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
# from IPython.core.display import display, HTML
from IPython.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %% [markdown]
# # <B>Data Load

# %%
df = pd.read_csv("../ml/datas/lec06_boston-house-price-data.csv")
df.columns = df.columns.str.lower()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    float64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.head(3)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
#
#    ptratio       b  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7

# %% [markdown]
# # <b> 회귀 모델 점수

# %%
y = df['medv']
X = df.drop('medv', axis=1)
print(X.shape,  y.shape)

X80,X20,y80,y20 = train_test_split(X, y, random_state=7825 )
print(X80.shape,X20.shape,y80.shape,y20.shape)
# Out:
# (506, 13) (506,)
# (379, 13) (127, 13) (379,) (127,)

# %%
model = XGBRegressor(random_state=4567) 
model.fit(X80, y80)
pred  = model.predict(X20)

mse       = mean_squared_error(y20        , pred)
rmse      = np.sqrt(mse)
print(f"mse:{mse:.4f}\t rmse:{rmse:.4f}")
print()
# Out:
# mse:9.0452	 rmse:3.0075

# %% [markdown]
# # <b> 딥러닝 모델 점수

# %%
model = Sequential([
    Dense(units=10, activation="relu" , input_dim=13 ),   #----- input layer
    Dense(units=16, activation="relu"                ),   #----- hidden layer 3
    Dense(units=24, activation="relu"                ),    
    Dense(units=8,  activation="relu"                ),
    Dense(units=1                                    )    #----- output layer   
 ])

# %%
model.compile(loss="mse", optimizer="adam",  metrics=["mse"])   #-------------------- l o m

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 10)                  │             140 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 24)                  │             408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │             200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 933 (3.64 KB)
#  Trainable params: 933 (3.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
res = model.fit(X80,y80,     epochs=50 ,   validation_data = (X20,y20)  )
# res
loss,mse = model.evaluate(X20, y20)
print(f"mse : {mse:.4f} , loss:{loss:.4f} , rmse : {np.sqrt(mse):.4f} " )
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 599.0286 - mse: 599.0286 - val_loss: 335.0281 - val_mse: 335.0281
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 248.6369 - mse: 248.6369 - val_loss: 137.6394 - val_mse: 137.6394
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 114.6682 - mse: 114.6682 - val_loss: 116.1094 - val_mse: 116.1094
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 109.6785 - mse: 109.6785 - val_loss: 107.7749 - val_mse: 107.7749
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 95.7495 - mse: 95.7495 - val_loss: 86.0225 - val_mse: 86.0225
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 85.8207 - mse: 85.8207 - val_loss: 73.3842 - val_mse: 73.3842
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 78.1568 - mse: 78.1568 - val_loss: 67.4501 - val_mse: 67.4501
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 73.8797 - mse: 73.8797 - val_loss: 61.5574 - val_mse: 61.5574
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 72.2543 - mse: 72.2543 - val_loss: 57.4814 - val_mse: 57.4814
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.2667 - mse: 69.2667 - val_loss: 57.0880 - val_mse: 57.0880
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 68.5914 - mse: 68.5914 - val_loss: 54.6512 - val_mse: 54.6512
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 67.8698 - mse: 67.8698 - val_loss: 54.1866 - val_mse: 54.1866
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 67.1517 - mse: 67.1517 - val_loss: 52.7777 - val_mse: 52.7777
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 66.8693 - mse: 66.8693 - val_loss: 53.1392 - val_mse: 53.1392
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 65.9469 - mse: 65.9469 - val_loss: 51.7507 - val_mse: 51.7507
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 65.3399 - mse: 65.3399 - val_loss: 51.7316 - val_mse: 51.7316
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 65.0134 - mse: 65.0134 - val_loss: 52.1774 - val_mse: 52.1774
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 64.3737 - mse: 64.3737 - val_loss: 51.0979 - val_mse: 51.0979
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 64.4731 - mse: 64.4731 - val_loss: 51.9286 - val_mse: 51.9286
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 64.2459 - mse: 64.2459 - val_loss: 50.2053 - val_mse: 50.2053
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.6837 - mse: 63.6837 - val_loss: 51.0306 - val_mse: 51.0306
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.4282 - mse: 63.4282 - val_loss: 49.2576 - val_mse: 49.2576
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 62.3534 - mse: 62.3534 - val_loss: 50.8952 - val_mse: 50.8952
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.4279 - mse: 63.4279 - val_loss: 49.3402 - val_mse: 49.3402
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 62.2801 - mse: 62.2801 - val_loss: 49.3870 - val_mse: 49.3870
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 62.1802 - mse: 62.1802 - val_loss: 49.2219 - val_mse: 49.2219
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 62.0614 - mse: 62.0614 - val_loss: 48.5646 - val_mse: 48.5646
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.8426 - mse: 61.8426 - val_loss: 49.3377 - val_mse: 49.3377
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.3559 - mse: 61.3559 - val_loss: 48.8399 - val_mse: 48.8399
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.2111 - mse: 61.2111 - val_loss: 48.6576 - val_mse: 48.6576
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.1299 - mse: 61.1299 - val_loss: 48.5689 - val_mse: 48.5689
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.7059 - mse: 60.7059 - val_loss: 48.1894 - val_mse: 48.1894
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.4871 - mse: 60.4871 - val_loss: 48.2231 - val_mse: 48.2231
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 60.2289 - mse: 60.2289 - val_loss: 47.9826 - val_mse: 47.9826
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.7074 - mse: 60.7074 - val_loss: 47.8229 - val_mse: 47.8229
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.7889 - mse: 59.7889 - val_loss: 47.2615 - val_mse: 47.2615
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.7099 - mse: 59.7099 - val_loss: 47.8359 - val_mse: 47.8359
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.3651 - mse: 59.3651 - val_loss: 47.8284 - val_mse: 47.8284
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.1747 - mse: 59.1747 - val_loss: 47.4780 - val_mse: 47.4780
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.1526 - mse: 59.1526 - val_loss: 47.0017 - val_mse: 47.0017
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.3538 - mse: 59.3538 - val_loss: 46.7690 - val_mse: 46.7690
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.7432 - mse: 59.7432 - val_loss: 46.7266 - val_mse: 46.7266
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.2399 - mse: 59.2399 - val_loss: 46.5624 - val_mse: 46.5624
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.5072 - mse: 58.5072 - val_loss: 46.4735 - val_mse: 46.4735
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.2804 - mse: 58.2804 - val_loss: 46.1341 - val_mse: 46.1341
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.4143 - mse: 57.4143 - val_loss: 45.9968 - val_mse: 45.9968
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.3724 - mse: 57.3724 - val_loss: 45.9102 - val_mse: 45.9102
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.3756 - mse: 57.3756 - val_loss: 45.3913 - val_mse: 45.3913
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.0295 - mse: 57.0295 - val_loss: 45.1619 - val_mse: 45.1619
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 56.8271 - mse: 56.8271 - val_loss: 44.9274 - val_mse: 44.9274
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 44.9274 - mse: 44.9274
# mse : 44.9274 , loss:44.9274 , rmse : 6.7028

# %%
res.history.keys()  
#res.history['accuracy']
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
vacc = res.history["val_mse"]
acc  = res.history["mse"]
plt.plot(range(50), vacc , label="vmse")
plt.plot(range(50), acc  , label="mse")
plt.legend()

plt.subplot(1,2,2)
vloss = res.history["val_loss"]
loss = res.history["loss"]
plt.plot(range(50),vloss , label="vloss")
plt.plot(range(50),loss  , label="loss")
plt.legend()
plt.show()
