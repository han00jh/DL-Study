# %% [markdown]
# # <b> lec03_딥러닝_회귀

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#----------------------------------------------------------------------------------- ML 모델
from xgboost import XGBRegressor 
#----------------------------------------------------------------------------------  DL모델 
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
#-----------------------------------------------------------------------------------  평가
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

sns.set()

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
# from IPython.core.display import display, HTML
from IPython.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %% [markdown]
# # <B>Data Load

# %%
df = pd.read_csv(r"C:\IT\workspace_ptyhon\basic\datas\Boston-house-price-data.csv")
df.columns = df.columns.str.lower()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    float64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# # <b> 머신러닝(회귀) 모델 점수

# %%
y = df['medv']
X = df.drop('medv', axis=1)
print(X.shape,  y.shape)

X80,X20,y80,y20 = train_test_split(X, y, random_state=7825 )
print(X80.shape,X20.shape,y80.shape,y20.shape)
# Out:
# (506, 13) (506,)
# (379, 13) (127, 13) (379,) (127,)

# %%
model = XGBRegressor(random_state=4567)
model.fit(X80, y80)
pred = model.predict(X20)

mse  = mean_squared_error(y20, pred)
rmse = np.sqrt(mse)
print(f"mse:{mse:.4f}\t rmse:{rmse:.4f}")
print()
# Out:
# mse:9.0452	 rmse:3.0075

# %% [markdown]
# # <b> 딥러닝 모델 점수

# %% [markdown]
# ### <b> 1. 라이브러리 준비 및 환경 설정

# %%
#----------------------------------------------------------------------------------   DL 모델
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
#----------------------------------------------------------------------------------  평가
from sklearn.metrics  import accuracy_score,      f1_score

# %% [markdown]
# ### <b> 2. 딥러닝 회귀 모델 구조 설계 (Model Build)

# %%
model = Sequential([
    Dense(units=10, activation="relu" , input_dim=13 ),   #----- input layer
    Dense(units=16, activation="relu"                ),   #----- hidden layer 3
    Dense(units=24, activation="relu"                ),    
    Dense(units=8,  activation="relu"                ),
    Dense(units=1                                    )    #----- output layer   
 ])

# %% [markdown]
# ### <b> 3. 모델 컴파일 및 학습 규칙 설정 (Compile)

# %%
model.compile(loss="mse", optimizer="adam",  metrics=["mse"])   #-------------------- l o m

# %% [markdown]
# ### <b> 4. 모델 요약 및 파람즈(Params) 확인

# %%
model.summary()

# param # : AI 모델이 학습을 통해 기억해야 할 '가중치(Weight)와 편향(Bias)의 총 개수 (공식의 개수)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 10)                  │             140 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 24)                  │             408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │             200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 933 (3.64 KB)
#  Trainable params: 933 (3.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### <b> 5. 딥러닝 모델 학습 실행 (Fit)

# %%
res = model.fit(   X80, y80,   epochs=50,   validation_data =(X20,y20)   )
res
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 506.5887 - mse: 506.5887 - val_loss: 131.9084 - val_mse: 131.9084
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 132.5712 - mse: 132.5712 - val_loss: 91.2740 - val_mse: 91.2740
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 90.5391 - mse: 90.5391 - val_loss: 65.9400 - val_mse: 65.9400
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.9159 - mse: 75.9159 - val_loss: 58.0473 - val_mse: 58.0473
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.2964 - mse: 69.2964 - val_loss: 51.6380 - val_mse: 51.6380
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 68.8449 - mse: 68.8449 - val_loss: 53.4654 - val_mse: 53.4654
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 67.6773 - mse: 67.6773 - val_loss: 51.6234 - val_mse: 51.6234
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 67.3611 - mse: 67.3611 - val_loss: 52.8513 - val_mse: 52.8513
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 65.7681 - mse: 65.7681 - val_loss: 51.9107 - val_mse: 51.9107
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 66.2573 - mse: 66.2573 - val_loss: 52.2328 - val_mse: 52.2328
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 64.6316 - mse: 64.6316 - val_loss: 51.1765 - val_mse: 51.1765
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 64.1617 - mse: 64.1617 - val_loss: 51.8052 - val_mse: 51.8052
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.8263 - mse: 63.8263 - val_loss: 51.5707 - val_mse: 51.5707
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.3497 - mse: 63.3497 - val_loss: 49.9699 - val_mse: 49.9699
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.1933 - mse: 63.1933 - val_loss: 49.7463 - val_mse: 49.7463
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.7796 - mse: 62.7796 - val_loss: 52.7351 - val_mse: 52.7351
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.6614 - mse: 62.6614 - val_loss: 49.0732 - val_mse: 49.0732
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 62.0944 - mse: 62.0944 - val_loss: 51.7178 - val_mse: 51.7178
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 61.9354 - mse: 61.9354 - val_loss: 49.7765 - val_mse: 49.7765
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 60.7602 - mse: 60.7602 - val_loss: 50.3580 - val_mse: 50.3580
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.6242 - mse: 60.6242 - val_loss: 48.6468 - val_mse: 48.6468
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.7941 - mse: 59.7941 - val_loss: 48.4350 - val_mse: 48.4350
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.4384 - mse: 59.4384 - val_loss: 48.6666 - val_mse: 48.6666
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.1619 - mse: 59.1619 - val_loss: 47.8873 - val_mse: 47.8873
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 59.4969 - mse: 59.4969 - val_loss: 49.0896 - val_mse: 49.0896
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.8841 - mse: 58.8841 - val_loss: 50.2375 - val_mse: 50.2375
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.1194 - mse: 58.1194 - val_loss: 46.9219 - val_mse: 46.9219
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.0938 - mse: 58.0938 - val_loss: 46.4512 - val_mse: 46.4512
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.0628 - mse: 57.0628 - val_loss: 48.0008 - val_mse: 48.0008
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.2212 - mse: 56.2212 - val_loss: 46.3747 - val_mse: 46.3747
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 55.2340 - mse: 55.2340 - val_loss: 45.8048 - val_mse: 45.8048
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.6280 - mse: 54.6280 - val_loss: 45.5034 - val_mse: 45.5034
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.0934 - mse: 54.0934 - val_loss: 45.2545 - val_mse: 45.2545
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 53.4927 - mse: 53.4927 - val_loss: 45.0241 - val_mse: 45.0241
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.0351 - mse: 53.0351 - val_loss: 45.8100 - val_mse: 45.8100
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.4550 - mse: 53.4550 - val_loss: 43.8017 - val_mse: 43.8017
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 52.1921 - mse: 52.1921 - val_loss: 44.9182 - val_mse: 44.9182
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.8594 - mse: 53.8594 - val_loss: 44.5531 - val_mse: 44.5531
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.5205 - mse: 51.5205 - val_loss: 47.5841 - val_mse: 47.5841
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.3471 - mse: 51.3471 - val_loss: 45.0799 - val_mse: 45.0799
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.5741 - mse: 50.5741 - val_loss: 42.4137 - val_mse: 42.4137
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.6662 - mse: 49.6662 - val_loss: 43.8435 - val_mse: 43.8435
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 50.3176 - mse: 50.3176 - val_loss: 43.4638 - val_mse: 43.4638
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.2507 - mse: 51.2507 - val_loss: 44.6627 - val_mse: 44.6627
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 49.0513 - mse: 49.0513 - val_loss: 45.1676 - val_mse: 45.1676
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.5086 - mse: 50.5086 - val_loss: 46.2902 - val_mse: 46.2902
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 51.4239 - mse: 51.4239 - val_loss: 46.5585 - val_mse: 46.5585
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.1686 - mse: 48.1686 - val_loss: 41.9230 - val_mse: 41.9230
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 47.9670 - mse: 47.9670 - val_loss: 41.1059 - val_mse: 41.1059
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 47.5666 - mse: 47.5666 - val_loss: 48.7762 - val_mse: 48.7762

# %% [markdown]
# ### <b> 6. 최종 성능 평가 및 오차(RMSE) 분석

# %%
loss,mse = model.evaluate(X20,y20)
print("==================================================== ")
print(f" mse : {mse:.4f}, loss : {loss:.4f},      rmse : {np.sqrt(mse):.4f}")
print("==================================================== ")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.8379 - mse: 39.8379
# ====================================================
#  mse : 39.8379, loss : 39.8379,      rmse : 6.3117
# ====================================================

# %% [markdown]
# > <b><big>  cf. ML 모델 돌렸을때 결과 </b></big> (이전 회귀 ML 모델 결과임) <br>
#
# ![{B8DF1983-8D5D-4ED9-BDD9-9FF40EA52DCC}.png](attachment:190c3805-3821-4078-95ea-a138c881972a.png)

# %% [markdown]
# ### <b> 학습 이력(History) 데이터 구조(keys) 확인

# %%
res.history.keys()
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %% [markdown]
# ### <b> 학습 결과 시각화 (Loss & MSE 그래프)

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
vacc = res.history["val_mse"]
acc  = res.history["mse"]
plt.plot(range(50), vacc , label="val_mse")
plt.plot(range(50), acc  , label="mse")
plt.legend()

plt.subplot(1,2,2)
vloss = res.history["val_loss"]
loss = res.history["loss"]
plt.plot(range(50),vloss , label="val_loss")
plt.plot(range(50),loss  , label="loss")
plt.legend()
plt.show();
