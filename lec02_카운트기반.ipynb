# %% [markdown]
# # <font size=6><b>Lec02.NLP 언어모델
# * NLP(자연어처리) + LLM(언어모델)
# * 자연어를 모델링하려고 단어 시퀀스(문장)에 확률을 할당하는 모델
#
# - N-gram : 단어 N개씩 시퀀스화 시켜서 조건부 확률 맞춰보기
# - 빈도기반 : BoW, TF-IDF
# - 유사도 기반

# %% [markdown]
# # <font size=6><b>Lec03.카운트 기반의 텍스트 표현(Count based word Representation)
# * https://wikidocs.net/book/2155

# %% [markdown]
# # <b><font color = red>★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★

# %% [markdown]
# # <b> <font color = red>DTM(Document Term Matrix)

# %% [markdown]
# # <b><font color = red> TF-IDF(Term Frequency-Inverse Document Frequency)

# %% [markdown]
# # <b><font color = red> BoW(Bag of Word)

# %% [markdown]
# # <b> <font color = red>유사도
