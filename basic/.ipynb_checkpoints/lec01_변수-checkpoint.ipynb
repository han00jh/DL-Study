# %% [markdown]
# <font size=6> lec o1. 변수

# %% [markdown]
# 값을 담는 그릇, 저장공간
# 메모리 저장공간
# 주소 : 4byte(32bit), 16진법(0123456789abcdef),ox(=16진법)
#     ex) ox1a45321e32541b..(32글자) = num(=변수)

# %% [markdown]
# 변수 종류
# 타입
#     정수int
#     실수 float, double
#     글자 str
#     불리언 True/False
#     날짜 Date(import)
#
# 연산(타입의 연산)
#     가감산 : +,-,*,/,%(나머지),//(몫)
#     우선순위 : 괄호()
#     연산 시 캐스팅(타입변환) 발생 가능
