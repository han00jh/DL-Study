# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("./datas/exam1.csv", encoding = "utf-8")
df2 = pd.read_csv("./datas/exam2.csv", encoding = "utf-8")

# %%
df1
# Out:
#     empno ename dname  score1  score2
# 0    1001   김길동   c01   100.0    70.0
# 1    1002   나길동   c01    90.0    80.0
# 2    1003   다길동   c02    80.0    90.0
# 3    1004   라길동   c02     NaN    60.0
# 4    1005   마길동   c02    90.0    90.0
# 5    1006   바길동   c01    70.0    90.0
# 6    1007   상길동   c03    80.0    80.0
# 7    1008   이길동   c01    90.0     NaN
# 8    1009   장길동   c01    60.0    90.0
# 9    1010   차길동   c03    90.0    70.0
# 10   1011   키길동   c03    70.0    80.0
# 11   1012   타길동   c01    80.0    80.0
# 12   1013   파길동   c03    70.0     NaN
# 13   1014   하길동   c03    80.0    40.0

# %%
df2
# Out:
#   deptno dname
# 0    c01   컴퓨터
# 1    c02   미디어
# 2    c03    보안

# %%
df2.loc[3] = ['c04', '정보통신']
df2
# Out:
#   deptno dname
# 0    c01   컴퓨터
# 1    c02   미디어
# 2    c03    보안
# 3    c04  정보통신

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   empno   14 non-null     int64
#  1   ename   14 non-null     object
#  2   dname   14 non-null     object
#  3   score1  13 non-null     float64
#  4   score2  12 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 688.0+ bytes

# %%
df1.isna().sum()
# Out:
# empno     0
# ename     0
# dname     0
# score1    1
# score2    2
# dtype: int64

# %%
df1.fillna({'score1':0,'score2':0}, inplace = True)
df1
# Out:
#     empno ename dname  score1  score2
# 0    1001   김길동   c01   100.0    70.0
# 1    1002   나길동   c01    90.0    80.0
# 2    1003   다길동   c02    80.0    90.0
# 3    1004   라길동   c02     0.0    60.0
# 4    1005   마길동   c02    90.0    90.0
# 5    1006   바길동   c01    70.0    90.0
# 6    1007   상길동   c03    80.0    80.0
# 7    1008   이길동   c01    90.0     0.0
# 8    1009   장길동   c01    60.0    90.0
# 9    1010   차길동   c03    90.0    70.0
# 10   1011   키길동   c03    70.0    80.0
# 11   1012   타길동   c01    80.0    80.0
# 12   1013   파길동   c03    70.0     0.0
# 13   1014   하길동   c03    80.0    40.0

# %%
df1.groupby(by ="dname")[['score1','score2']].mean()
# Out:
#           score1     score2
# dname
# c01    81.666667  68.333333
# c02    56.666667  80.000000
# c03    78.000000  54.000000

# %% [markdown]
# * dname별 score1 min,max, score2평균

# %%
df1.groupby(by="dname").agg({'score1':['min','max'],'score2':['mean']})
# Out:
#       score1            score2
#          min    max       mean
# dname
# c01     60.0  100.0  68.333333
# c02      0.0   90.0  80.000000
# c03     70.0   90.0  54.000000

# %% [markdown]
# * df1,df2조인해서 출력

# %%
df = pd.merge(df1, df2, how='left', left_on="dname", right_on="deptno")
df
# Out:
#     empno ename dname_x  score1  score2 deptno dname_y
# 0    1001   김길동     c01   100.0    70.0    c01     컴퓨터
# 1    1002   나길동     c01    90.0    80.0    c01     컴퓨터
# 2    1003   다길동     c02    80.0    90.0    c02     미디어
# 3    1004   라길동     c02     0.0    60.0    c02     미디어
# 4    1005   마길동     c02    90.0    90.0    c02     미디어
# 5    1006   바길동     c01    70.0    90.0    c01     컴퓨터
# 6    1007   상길동     c03    80.0    80.0    c03      보안
# 7    1008   이길동     c01    90.0     0.0    c01     컴퓨터
# 8    1009   장길동     c01    60.0    90.0    c01     컴퓨터
# 9    1010   차길동     c03    90.0    70.0    c03      보안
# 10   1011   키길동     c03    70.0    80.0    c03      보안
# 11   1012   타길동     c01    80.0    80.0    c01     컴퓨터
# 12   1013   파길동     c03    70.0     0.0    c03      보안
# 13   1014   하길동     c03    80.0    40.0    c03      보안
