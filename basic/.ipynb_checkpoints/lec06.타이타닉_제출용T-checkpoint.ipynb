# %% [markdown]
# <font size=6> <b>lec06. [실습] Titanic - DataFrame

# %% [markdown]
# ![image.png](attachment:9f7ec251-b240-41f7-80bc-fc3faa8de318.png)
# * ref : https://www.kaggle.com/competitions/hw5-titantic-competition-cs189sp23

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

#    패키지   모듈                   메서드  
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
# from IPython.core.display import display, HTML
from IPython.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %% [markdown]
# # <b>Data Load

# %%
train = pd.read_csv("./datas/titanic/train.csv")
test = pd.read_csv("./datas/titanic/test.csv")
submission = pd.read_csv("./datas/titanic/gender_submission.csv")

# %% [markdown]
# ## 가공을 위한 train_test 합치기

# %%
print(train.shape, test.shape)
train_test = pd.concat([train, test], axis=0)
print(train_test.shape)
# Out:
# (891, 12) (418, 11)
# (1309, 12)

# %%
train_test[889: 894]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 889          890       1.0       1             Behr, Mr. Karl Howell    male
# 890          891       0.0       3               Dooley, Mr. Patrick    male
# 0            892       NaN       3                  Kelly, Mr. James    male
# 1            893       NaN       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2            894       NaN       2         Myles, Mr. Thomas Francis    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 889  26.0      0      0  111369  30.0000  C148        C
# 890  32.0      0      0  370376   7.7500   NaN        Q
# 0    34.5      0      0  330911   7.8292   NaN        Q
# 1    47.0      1      0  363272   7.0000   NaN        S
# 2    62.0      0      0  240276   9.6875   NaN        Q

# %% [markdown]
# ## 컬럼 소문자 변경

# %%
train_test.columns = train_test.columns.str.lower()

# %%
train_test.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %% [markdown]
# ## 구조 : info()

# %%
train_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  1309 non-null   int64
#  1   survived     891 non-null    float64
#  2   pclass       1309 non-null   int64
#  3   name         1309 non-null   object
#  4   sex          1309 non-null   object
#  5   age          1046 non-null   float64
#  6   sibsp        1309 non-null   int64
#  7   parch        1309 non-null   int64
#  8   ticket       1309 non-null   object
#  9   fare         1308 non-null   float64
#  10  cabin        295 non-null    object
#  11  embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
train['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # <b>EDA (Exploratory Data Analysis)
# * 시각화(visualizations), 통계(statistics)

# %% [markdown]
# ## 데이터 분포도
# * train & test 분포도 확인

# %%
plt.figure(figsize=(10,5))
train.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# # <b>전처리 & 가공
# * Feature Engineering

# %% [markdown]
# <pre>
#
# 'cabin'           : 생존관계 확인 vs. 'survived'  --> drop
# 'embarked'        : 생존관계   vs. 'survived'
#                     결측처리(최빈), 인코딩
#
# 바이닝(구간화)     : 'age'
# 호칭자르기         : 'name'
# 결측처리           : 'age'(평균...??), 'embarked'(최빈)
#
# 버리기            : 'passengerid', 'ticket' ....  'cabin'
# 인코딩(글자->숫자) : 'sex' ... 'embarked'
# 파생변수(신규변수) : 'family_cnt' = 'sibsp' +  'parch' + 1
# 파생변수(신규변수) : 'fare_rate' = 'fare' / 'family_cnt'

# %% [markdown]
# ## embarked
# * 생존관계와의 뚜렷한 상관성은 보이지 않는듯 하다.
# * 결측처리(최빈), 인코딩

# %%
train_test.fillna( {"embarked":  train_test['embarked'].mode()[0]} , inplace=True)

# %%
train_test      ['embarked'].isna().sum()
# Out:
# np.int64(0)

# %%
train_test['embarked'] = train_test['embarked'].map( {"S":0,  "C":1, "Q":2}  )

# %%
train_test      ['embarked'].value_counts()
# Out:
# embarked
# 0    916
# 1    270
# 2    123
# Name: count, dtype: int64

# %% [markdown]
# ## age
# * 결측처리

# %%
train_test[ train_test['age'].isna() == True ] .head(2)
# Out:
#     passengerid  survived  pclass                          name   sex  age  \
# 5             6       0.0       3              Moran, Mr. James  male  NaN
# 17           18       1.0       2  Williams, Mr. Charles Eugene  male  NaN
#
#     sibsp  parch  ticket     fare cabin  embarked
# 5       0      0  330877   8.4583   NaN         2
# 17      0      0  244373  13.0000   NaN         0

# %% [markdown]
# ### 호칭 별 평균 나이

# %%
train_test['name2'] = train_test['name'].str.extract("\,\s([\sA-Za-z]+\.)\s")
train_test['name2'].isna().sum()
# Out:
# np.int64(0)

# %%
train_test['age'] = train_test.groupby('name2') ['age'] .transform( lambda ag : ag.fillna(ag.mean()) )

# %% [markdown]
# ### 바이닝(bining)

# %%
train_test['age2'] = (train_test['age']//10).astype(int)

# %%
train_test.head(2)
# Out:
#    passengerid  survived  pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
#
#    parch     ticket     fare cabin  embarked name2  age2
# 0      0  A/5 21171   7.2500   NaN         0   Mr.     2
# 1      0   PC 17599  71.2833   C85         1  Mrs.     3

# %% [markdown]
# ## 'passengerid', 'ticket', 'cabin', 'name'
# * 버리기            : 'passengerid', 'ticket' ....  'cabin'

# %% [markdown]
# ### drop()

# %%
train_test.drop(['passengerid', 'ticket','cabin', 'name'], axis=1, inplace=True)

# %% [markdown]
# ## sex
# * 인코딩 : 글자 --> 숫자 변경
# * male : 1 , female : 0

# %% [markdown]
# ### 인코딩

# %%
train_test['sex'] = train_test['sex'].map( {"female":0,  "male":1} )

# %% [markdown]
# ## name2

# %% [markdown]
# ### 인코딩

# %%
le = LabelEncoder()
le.fit(  train_test['name2']   )                           #--------
train_test['name2'] = le.transform(  train_test['name2']    )  #--------
train_test['name2'].value_counts()
# Out:
# name2
# 12    757
# 9     260
# 13    197
# 8      61
# 15      8
# 4       8
# 1       4
# 7       2
# 10      2
# 14      2
# 11      1
# 2       1
# 16      1
# 6       1
# 0       1
# 17      1
# 5       1
# 3       1
# Name: count, dtype: int64

# %% [markdown]
# ## family_cnt , fare_rate

# %% [markdown]
# * 파생(신규)피쳐 : 'family_cnt' = 'sibsp' +  'parch' + 1
# * 파생(신규)피쳐 : 'fare_rate' = 'fare' / 'family_cnt'

# %%
train_test['family_cnt'] = train_test['sibsp'] + train_test['parch'] + 1

# %%
train_test['fare_rate'] =   train_test['fare']  / train_test['family_cnt']

# %% [markdown]
# ## test 결측처리 : fare, fare_rate

# %% [markdown]
# * pclass=3  fare_rate 평균

# %%
train_test[train_test['pclass']==3]['fare_rate'].mean()
# Out:
# np.float64(7.967487486548292)

# %%
test[test['Fare'].isna()]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked
# 152   NaN   NaN        S

# %%
#test.loc[  test['Fare'].isna() , 'Fare'  ] = 7.97
test.loc[  test['Fare'].isna() , 'Fare'  ] = train_test[train_test['pclass']==3]['fare_rate'].mean()

# %%
train_test.loc[ (train_test.index==152) & (train_test['fare'].isna()), ['fare','fare_rate'] ]  = [7.97, 7.97]

# %%
train_test[(train_test.index==152)  ]
# Out:
#      survived  pclass  sex   age  sibsp  parch  fare  embarked  name2  age2  \
# 152       0.0       3    1  55.5      0      0  8.05         0     12     5
# 152       NaN       3    1  60.5      0      0  7.97         0     12     6
#
#      family_cnt  fare_rate
# 152           1       8.05
# 152           1       7.97

# %% [markdown]
# # <b>1차가공 최종
# * <font color=red size=4><b>올수치, 결측제로

# %%
train_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    float64
#  1   pclass      1309 non-null   int64
#  2   sex         1309 non-null   int64
#  3   age         1309 non-null   float64
#  4   sibsp       1309 non-null   int64
#  5   parch       1309 non-null   int64
#  6   fare        1309 non-null   float64
#  7   embarked    1309 non-null   int64
#  8   name2       1309 non-null   int64
#  9   age2        1309 non-null   int64
#  10  family_cnt  1309 non-null   int64
#  11  fare_rate   1309 non-null   float64
# dtypes: float64(4), int64(8)
# memory usage: 132.9 KB

# %% [markdown]
# # <b>학습
# * https://scikit-learn.org/stable/

# %% [markdown]
# ## <b>[1] train test 분리

# %% [markdown]
# ``` python
# sklearn.model_selection.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)

# %% [markdown]
# * <b>train_test를 원래 train, test로 분리
# * <b>test의 survived 피쳐는 삭제

# %%
train.shape , test.shape
# Out:
# ((891, 12), (418, 11))

# %%
# train = train_test[train_test['survived'].notna()]
# test = train_test[train_test['survived'].isna()]
# test = test.drop(['survived'], axis=1)

# %%
train_test.iloc[ : 891, : ].shape ,  train_test.iloc[ 891: , 1: ].shape
# Out:
# ((891, 12), (418, 11))

# %%
train = train_test.iloc[ : 891, : ]
test = train_test.iloc[ 891: , 1: ]

# %%
train.shape , test.shape
# Out:
# ((891, 12), (418, 11))

# %% [markdown]
# * <b>y(답안) X(문제) 분리

# %%
y = train['survived']
X = train.drop('survived', axis=1)
y.shape,  X.shape
# Out:
# ((891,), (891, 11))

# %%
X.head(2)
# Out:
#    pclass  sex   age  sibsp  parch     fare  embarked  name2  age2  \
# 0       3    1  22.0      1      0   7.2500         0     12     2
# 1       1    0  38.0      1      0  71.2833         1     13     3
#
#    family_cnt  fare_rate
# 0           2    3.62500
# 1           2   35.64165

# %%
y.head()
# Out:
# 0    0.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0
# Name: survived, dtype: float64

# %% [markdown]
# * <b> 8 : 2 분리 ::: 학습용 문제/답 , 셀프테스트용 문제/답

# %%
train.shape
# Out:
# (891, 12)

# %%
X80, X20 ,   y80, y20 = train_test_split(X, y, test_size=0.2, random_state=85479, shuffle=True, stratify=y)
X80.shape,  X20.shape, y80.shape,  y20.shape
# Out:
# ((712, 11), (179, 11), (712,), (179,))

# %% [markdown]
# ## <b>[2] 모델 선택
# * y (타켓:survived)를 보고 회귀 or 분류 결정

# %% [markdown]
# <pre><b><font color=red>
# Supervised learning : 지도학습
#  - 회귀(Regression) : 연속형 (4987.1245  5001.3827)
#         Ridge, Lasso, ElasticNet ....... DecisionTreeRegressor , SVR
#  - 분류(Classification) : 이산형   (0,1,2)
#         LogisticRegression       ....... DecisionTreeClassifier , SVC
#
# Unsupervised learning : 비지도학습
#  - 군집(clustering)

# %% [markdown]
# ``` python
# 하이퍼 파라미터 튜닝 : 모델 예측력 영향을 줌
#
# class sklearn.linear_model.LogisticRegression(penalty='deprecated', *, C=1.0, l1_ratio=0.0, dual=False, tol=0.0001, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='lbfgs', max_iter=100, verbose=0, warm_start=False, n_jobs=None)
#
# class sklearn.tree.DecisionTreeClassifier(*, criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, class_weight=None, ccp_alpha=0.0, monotonic_cst=None)

# %%
lr = LogisticRegression()
dt = DecisionTreeClassifier()

# %% [markdown]
# ## <b>[3] 학습 fit(X80, y80)
# * 80% 문제지 답안지

# %%
lr.fit(X80, y80)
dt.fit(X80, y80)
# Out:
# C:\IT\workspace_python\.venv\lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# DecisionTreeClassifier()

# %% [markdown]
# ## <b>[4]  예측 predict(X20)
# * 20% 문제지만  ..  20%답안지는 보여주지 않는다

# %%
lr_pred = lr.predict(X20)
dt_pred = dt.predict(X20)

# %% [markdown]
# ## <b>[5]  점수 (모델 예측력) 평가
# * y20(20%진짜답안), dt_pre(컴퓨터가 예측한 답안)
# * https://scikit-learn.org/stable/modules/model_evaluation.html

# %% [markdown]
# ``` python
# sklearn.metrics.accuracy_score(y_true, y_pred, *, normalize=True, sample_weight=None)

# %%
lr_accuracy = accuracy_score(y20, lr_pred)
dt_accuracy = accuracy_score(y20, dt_pred)
print(lr_accuracy)
print(dt_accuracy)
# Out:
# 0.7932960893854749
# 0.7597765363128491

# %% [markdown]
# ## <b>[6] 공모전 제출용 답안지 생성

# %%
test_pred = lr.predict(test)

# %%
test_pred.shape
# Out:
# (418,)

# %%
submission.shape
# Out:
# (418, 2)

# %%
submission['Survived'] = test_pred
submission['Survived'] = submission['Survived'].astype(int)
submission[submission['Survived'].isna() ]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived]
# Index: []

# %%
submission.head(2)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0

# %% [markdown]
# ## <b>[7] 공모전 제출
# * submission DataFrame을 File 로 저장해서 제출

# %%
submission.to_csv("./lec06_공모전제출답안_v1차.csv", index=False)

# %% [markdown]
# ![image.png](attachment:1a324f1c-9dab-455a-b8d8-435031496a66.png)

# %% [markdown]
# ![image.png](attachment:4f0ff98b-9665-4d5a-9578-c5849d1415f3.png)

# %% [markdown]
# ![image.png](attachment:bb02a6e7-1864-4153-ac28-abe05cd6de9c.png)

# %%
10515 / 12939
# Out:
# 0.812659401808486
