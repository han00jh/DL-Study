# %% [markdown]
# # lec09_크롤링

# %% [markdown]
# # 모델

# %%
# ! pip install beautifulsoup4 , selenium

# %% [markdown]
# # 크롬 드라이버

# %% [markdown]
# ![image.png](attachment:5d4e477c-9540-49ef-8fb5-5aafbb854888.png)

# %% [markdown]
# ![image.png](attachment:fbeacac2-4b20-4c40-a7cb-f5b0724a5266.png)
